# %%
print('Привет мир!') # Если нужно, что то выполнить. Ставлю курсор в нужную ячейку и жму Shift + Enter
# Out:
# Привет мир!

# %%
while True: # Этот код зациклин. * - показывает, что есть ошибка в коде! Нажав на STOP увижу у какой строке ошибка.
    i = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 2>()
#       1 while True: # Этот код зациклин. * - показывает, что есть ошибка в коде! Нажав на STOP увижу у какой строке ошибка.
# ----> 2     i = 1
#
# KeyboardInterrupt:

# %%
h = 0
while h < 10: # Нормальный цикл, без ошибок
    h += 1

# %%
# Чтобы добавить пустую строку жму Alt + Enter

# %% [markdown]
# 1. Определение переменной.

# %%
x = 2

# %%
x # Можно написать просто название переменной и получить её значение, как писать print(x)
# Out:
# 2

# %%
x + 12
# Out:
# 14

# %%
x = 11 # Определил переменную и задал её значение.
y = 22
x + y # Можно писать арифметические операции.

# %% [markdown]
# 2. Метод.

# %%
def fib(n):  # Метод
    if n <= 1:
        return 1
    else:
        return fib(n - 1) + fib(n - 2)

# %%
fib(12) # Вызов метода и передача в него значения.
# Out:
# 233

# %% [markdown]
# 3. Определение списка.

# %%
li = [] # Определение списка.
for i in range(1, 10): # Цикл от 1 до 9
    li.append(i) # Дабавляет элемент в список li
li # Вывод списка Li
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
fibs = [(n, fib(n)) for n in range(1, 10)] # Если нужно получить лист кортежей, используя List Comprehension
fibs
# Out:
# [(1, 1), (2, 2), (3, 3), (4, 5), (5, 8), (6, 13), (7, 21), (8, 34), (9, 55)]

# %% [markdown]
# 4. Квадратные уравнения

# %%
# Квадратные уравнения
from math import sqrt # Можно импортировать модули или отдельные библиотеки.

def solve(a, b, c): # Метод
    d = b**2 -4*a*c # Расчет дискриминанта
    if d >= 0:
        x1 = (-b + sqrt(d)) / (2 * a) # Расчет первого корня
        x2 = (-b - sqrt(d)) / (2 * a) # Второго
        return (x1, x2)
    else:
        return 'Вещественных корней нет'

# %%
solve(0.5, 0.125, 0)
# Out:
# (0.0, -0.25)

# %%
solve(1, 2, 3)
# Out:
# 'Вещественных корней нет'

# %% [markdown]
# 5. Комплексные числа.

# %%
# Язык Python позволяет работать с комплексными числами на прямую.
z1 = complex(1, 2) # Действительная часть = 1, вещественная часть = 2
z2 = complex(3, 5)
z1, z2
# ((1+2j), (3+5j)) # j - обозначается мнимая часть, а в математике i.
# Out:
# ((1+2j), (3+5j))

# %%
'z1 = ({}, {})'.format(z1.imag, z2.real) # Если нужно получить отдельно мнимую часть и действительную.
# Out:
# 'z1 = (2.0, 3.0)'

# %% [markdown]
# 6. Импорт модуля.

# %%
import cmath # Если я импортирую модуль позволяющий вычислять, в том числе корни комплексных чисел

def csolve(a, b, c):
    d = b**2 - 4*a*c
    x1 = (-b + cmath.sqrt(d)) / (2 * a) # Расчет первого корня
    x2 = (-b - cmath.sqrt(d)) / (2 * a) # Второго
    return (x1, x2)

# %%
csolve(1, 2, 5) # В ответе будет два комплексных корня.
# Out:
# ((-1+2j), (-1-2j))

# %% [markdown]
# 7. Использование Map, lambda.

# %%
# Пример использования Map
f = lambda x: x**3 #  Определяю lambda
list(map(f, range(1, 5))) # Подсовываю lambda, в map, чтобы получить 4 куба ([1, 8, 27, 64])
# Out:
# [1, 8, 27, 64]

# %% [markdown]
# 8. PIP.

# %%
# Как и ранее я могу использовать репозиторий с библиотеками, скачивая их, устанавливая и используя в своих 
# записных книжках. Для этого запускаю программу Anaconda Prompt и пишу какую библиотеку нужно установить.
# Пример: pip install isodd

# %%
#PIP
import matplotlib.pyplot as plt # matplotlib - библиотека.

# %%
import random

random.randint(1, 10) # Генератор случайных чисел.
# Out:
# 9

# %%
f = lambda x: random.randint(1, 10) # Функция, которая выдает набор случайных чисел.
points = list(map(f, range(1, 10)))
points
# Out:
# [5, 3, 2, 3, 3, 1, 8, 10, 1]

# %%
# plt.plot(points, 'ro') # Строит точечную диаграмму. 'ro' - это маркер, чтобы отображение было точками.
# Вижу артифакт [<matplotlib.lines.Line2D at 0x1a27717e400>] - чтобы убрать нужно присвоить значение фукции переменной.
p = plt.plot(points, 'b.') # Маркеры: 'b-' - (сплошная синяя линия); 'b.' - (синии точки)

# %%
plt.plot(points)
plt.show() # Если не указывать маркер.

# %%
x = list(map(f, range(1, 10))) # Если нужно установить какой-то случайный набор
y = list(map(f, range(1, 10)))
print(x)
print(y)
plt.plot(x, y, 'yH')
plt.show()
# Виды маркеров (первый элемент) - это цвет: r - red, y - yellow, b - black
# Второй элемент: '.', ',', ' ', 'o', 'v', '^', '<', '>', '1', '2', '3', '4', '8', 's', 'p', 'P', '*',
# 'h', 'H', '+', 'x', 'X', 'd', 'D', '|', '_',
# Out:
# [1, 5, 2, 5, 4, 1, 5, 1, 8]
# [9, 6, 9, 1, 7, 8, 2, 1, 8]

# %%
x = list(range(1, 200))
fx = [i*i for i in x]

# Настройки matplotlib.
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.html?highlight=pyplot#
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axes.html#matplotlib.pyplot.axes  - рабочая ссылка.

plt.axes(facecolor= 'black') # Можно делать монипуляции с графиком. Если нужно сделать заливку фона.
# plt.axes(facecolor= 'white')
plt.plot(x, fx)
plt.show()

# %% [markdown]
# 9. Настройки matplotlib.

# %%
# Настройки.
# https://matplotlib.org/stable/tutorials/introductory/customizing.html

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl

x = list(range(-200, 200))
fx = [i**2 + 2*i - 3 for i in x]

# Могу менять внешний вид графика, изменяя маркеры.
mpl.rcParams['lines.linewidth'] # 2
mpl.rcParams['lines.linestyle'] # '-.' #'--'
mpl.rcParams['lines.color'] # 'CO'

plt.axes(facecolor='white')
plt.plot(x, fx)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2], [1, -1], 'ro', markerfacecolor = 'red') # Пример отображения списки списков точками.
plt.show()

# %%
import numpy as np
from math import sqrt
import matplotlib.pyplot as plt

x = list(range(0, 500, 2))
y = list(map(lambda a: sqrt(a), x))

fig, ax = plt.subplots()

ax.plot(x, y)
ax.grid()

# Если еужно сделать наименование осей и сетку в таблице.
ax.set_xlabel('x')
ax.set_ylabel('sqrt(x)')

plt.show()

# %%
import matplotlib.pyplot as plt
import random

# random.randint(1, 10)

vx = [1.0, 2.0, 3.0] # Первая вершина треугольника
vy = [1.0, 2.0, 1.0] # Вторая

sx = vx[0]
sy = vy[0]

px = []
py = []

for i in range(1, 1000):
    r = random.randint(0, 2) # Определяю середину
    sx = (sx + vx[r]) / 2 # Определяю нужные точки
    sy = (sy + vy[r]) / 2
    px.append(sx) # Добавляю точки в лист px
    py.append(sy)
    
plt.plot(px, py, 'o')
plt.show()

# %%
import random
import matplotlib.pyplot as plt

# Тоже самое, но более детально.

x = [1.0, 2.0, 3.0]
y = [1.0, 2.0, 1.0]

sx = x[0]
sy = y[0]

px = []
py = []

for i in range(1, 10000):
    r = random.randint(0, 2)
    sx = (sx + x[r]) / 2
    sy = (sy + y[r]) / 2
    px.append(sx)
    py.append(sy)
    
fig, ax = plt.subplots()

# Маркеры цветов: 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w', RGB: #00ff00
ax.scatter(px, py, c = 'red', s = 1)
ax.set_facecolor('black')

# ax.grib()
# ax.set_xlabel('')
# ax.set_ylabel('')
fig.set_figwidth(15)
fig.set_figheight(10)
plt.show()

# %%
# Можно применять в области аналитики или проводить свои эксперементы
# Пример: Есть игральная кость. Теория вероятности говорит, что чем больше я буду опытов проделывать, тем скорее всего
# распределени будет одинаковым. Вопрос, сколько нужно опытов проделать, чтобы получить равновероятностное распределение.

# %%
import random
import matplotlib.pyplot as plt

count = 1000 # Будет выполнено count опытов.
x = list(range(1, 7))
y = [0 for i in x]

fig, ax = plt.subplots()

# Создаю отдельный список из 6-ти нулей. Каждый из которых будет обозначать сколько раз выпала та или иная грань.
for _ in range(count):
    y[random.randint(0, 5)] += 1
    
ax.bar(x, y)

y.sort()
# print('{}%'.format(round((y[5] - y[0]) / count * 100, 3)))
stat = [f'{i + 1}: {round(y[i] / count * 100)}%' for i in range(0, 6)]
print(stat)
plt.show() # Увижу гистограмму распределения и какое значение выпало в процентном соотношении.
# Out:
# ['1: 16%', '2: 16%', '3: 16%', '4: 17%', '5: 17%', '6: 18%']

# %%
from sympy import * # Библиотека sympy (pip install sympy) - для того, чтобы работать с мат. уровнениями, вычисление
# производных, с решением систем квадратных уравнений, линейных и нелинейных уравнений, с функциями многих переменных,
# нахождение частных производных и т.д.
from sympy.plotting import plot
init_printing()

# %%
x = Symbol('x') # Определяю переменную x, чтобы x воспренимать как симкольную 'x'

# %%
f = x + 2022 # Определяю f
f
# Out:
# x + 2022

# %%
f.subs(x, -77) # Так можно посчитать чему будет равна значение функции в точке -77
# Out:
# 1945

# %%
f.subs(x, -210)
# Out:
# 1812

# %%
plot(f)
print(f) #Если нужно просто напечатать функцию.Чтобы настройки из предыдущего кода убрать перезапускаю и инициализирую снова.
# Out:
# x + 2022

# %%
g = sin(x+x) / x # Так можно определять сложные функции.
plot(g)
print(g)
# Out:
# sin(2*x)/x

# %%
h = x**2
h
# Out:
#  2
# x

# %%
plot(h)
h
# Out:
#  2
# x

# %%
h = -h

# %%
plot(h)
h
# Out:
#   2
# -x

# %%
a = 1 # -1 график будет в другую сторону.
b = 3
c = 4
h = a*x**2 + b*x+c
h
# Out:
#  2
# x  + 3⋅x + 4

# %%
plot(h)
h
# Out:
#  2
# x  + 3⋅x + 4

# %%
solve(h, x) # Получу корни уравнения
# Out:
# ⎡  3   √7⋅ⅈ    3   √7⋅ⅈ⎤
# ⎢- ─ - ────, - ─ + ────⎥
# ⎣  2    2      2    2  ⎦

# %%
q = x / (x+2)
q
# Out:
#   x
# ─────
# x + 2

# %%
plot(q) # Вижу на графике чепуху, т.к. на 0 делить нельзя. В тоже время sympy попытался, что-то построить.
# Нужно быть внимательным!!!

# %%
fun1 = plot(q, (x, -10, -2.1), show = False) # т.к. точка -2 выбивается из графика, то можно взять часть графика от -10 до -2.1
fun2 = plot(q, (x, -1.9, 10), show = False) # и от -1.9 до 10
fun1.append(fun2[0]) # Собираю воедино 
fun1.show()

# %%
x = Symbol('x')
y = 1*x**2 + 2*x - 10
solve(y)

# %%
res = plot(y, (x, -5, 5))
